# %% [markdown]
# ## MLFLow Tracking Server

# %%
import mlflow
import os

os.environ["MLFLOW_TRACKING_USERNAME"] = "user"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "xxx"

# %%
mlflow.set_tracking_uri("https://mlflow.new-nation.church")

# %%
mlflow.set_experiment("Check localhost connection3")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Dewey",2)
# Out:
# 2025/07/22 21:24:43 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection3' does not exist. Creating a new experiment.
# 🏃 View run useful-rat-517 at: https://mlflow.new-nation.church/#/experiments/10/runs/06136ce05b9a456bba495c49c372a7e4
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/10

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Dewey1",2)
# Out:
# 🏃 View run melodic-croc-185 at: https://mlflow.new-nation.church/#/experiments/10/runs/73ee7a2a2dec40a6bc7dc51d16cb8d3e
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/10

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Dewey2",2)
# Out:
# 🏃 View run dashing-deer-323 at: https://mlflow.new-nation.church/#/experiments/10/runs/c9dcce92008b4d1da9e1010aab4b6947
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/10
