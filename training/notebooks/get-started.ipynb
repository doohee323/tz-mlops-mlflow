# %% [markdown]
# ## MLFLow Tracking Server

# %%
# 환경 설정: 터미널에서 먼저 실행
#   cd /path/to/tz-mlops-mlflow && source env-airflow/bin/activate && pip install -r requirements.txt
# Jupyter는 env-airflow 커널로 실행 (Kernel → Change Kernel → Python 3 (env-airflow))

# %%
import mlflow
import os

os.environ["MLFLOW_TRACKING_USERNAME"] = "user"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "xxx"

# %%
mlflow.set_tracking_uri("https://mlflow.drillquiz.com")

# %%
mlflow.set_experiment("Check localhost connection3")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Dewey",2)
# Out:
# 2026/02/10 16:30:46 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection3' does not exist. Creating a new experiment.
# 🏃 View run gentle-moose-903 at: https://mlflow.drillquiz.com/#/experiments/1/runs/f97b1fd10c164d8f95428442df3487ce
# 🧪 View experiment at: https://mlflow.drillquiz.com/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Dewey1",2)
# Out:
# 🏃 View run fun-bug-36 at: https://mlflow.drillquiz.com/#/experiments/1/runs/76619eb9a6de455fb2927fa680ad555d
# 🧪 View experiment at: https://mlflow.drillquiz.com/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Dewey2",2)
# Out:
# 🏃 View run delicate-conch-748 at: https://mlflow.drillquiz.com/#/experiments/1/runs/adff891393a043cea826afc495abe025
# 🧪 View experiment at: https://mlflow.drillquiz.com/#/experiments/1
