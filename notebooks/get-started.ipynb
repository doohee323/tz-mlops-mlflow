# %% [markdown]
# ## MLFLow Tracking Server

# %%
import mlflow
import os

os.environ["MLFLOW_TRACKING_USERNAME"] = "user"
os.environ["MLFLOW_TRACKING_PASSWORD"] = "xxx"

# %%
mlflow.set_tracking_uri("https://mlflow.new-nation.church")

# %%
mlflow.set_experiment("Check localhost connection2")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Krish",2)
# Out:
# 🏃 View run brawny-lark-933 at: https://mlflow.new-nation.church/#/experiments/2/runs/b9cfbae014df4fd799995649cb4f4617
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/2

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Krish1",2)
# Out:
# 🏃 View run adaptable-kite-764 at: https://mlflow.new-nation.church/#/experiments/2/runs/b145a9983d2342508c1fce801d88de86
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/2

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Krish2",2)
# Out:
# 🏃 View run judicious-sheep-939 at: https://mlflow.new-nation.church/#/experiments/2/runs/869a98ab38f145b584c65bd2b0a8cef1
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/2
