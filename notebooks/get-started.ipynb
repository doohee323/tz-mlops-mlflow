# %% [markdown]
# ## MLFLow Tracking Server

# %%
import mlflow

# %%
mlflow.set_tracking_uri("https://mlflow.new-nation.church")

# %%
mlflow.set_experiment("Check localhost connection2")

with mlflow.start_run():
    mlflow.log_metric("test",1)
    mlflow.log_metric("Krish",2)
# Out:
# 2025/07/20 18:01:54 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection' does not exist. Creating a new experiment.
# 🏃 View run overjoyed-ray-550 at: https://mlflow.new-nation.church/#/experiments/1/runs/74b05fa08a0e4412ba9ebe6272590976
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test1",1)
    mlflow.log_metric("Krish1",2)
# Out:
# 🏃 View run calm-ram-532 at: https://mlflow.new-nation.church/#/experiments/1/runs/82ef75b49daf416f857cfaa1e1a4b320
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric("test2",1)
    mlflow.log_metric("Krish2",2)
# Out:
# 🏃 View run honorable-sheep-219 at: https://mlflow.new-nation.church/#/experiments/1/runs/2f0b243bd314442b94720df174ac0a6e
# 🧪 View experiment at: https://mlflow.new-nation.church/#/experiments/1
